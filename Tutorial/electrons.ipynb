# %%
from yaiv import electron as el
# %load_ext autoreload
# %autoreload 2

# %%
#bands=el.electronBands('data/qe/results_bands/Si.bands.pwo')
bands=el.electronBands('data/vasp/RESULTS/OUTCAR_BS')
#bands=el.electronBands('data/vasp/RESULTS/EIGENVAL_BS')

# %%
bands.plot()
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
phonons=el.phononBands('data/qe/results_matdyn/Si.freq')
# Out:
# /u/51/gutierm2/unix/Software/YAIV/build/__editable__.yaiv-0.3.1-py3-none-any/yaiv/electron.py:54: UserWarning: Could not read lattice from data/qe/results_matdyn/Si.freq. Lattice set to None.
#   warnings.warn(

# %%
phonons.plot()
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
